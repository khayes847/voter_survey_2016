# %%
import warnings
import pandas as pd
import numpy as np
warnings.filterwarnings('ignore')
pd.set_option("max_columns", 100)
pd.set_option("max_rows", 100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import swifter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data/survey.csv', index_col='case_identifier')

# %%
data.head()
# Out:
#                  weight PARTY_AGENDAS_rand_2016          pp_primary16_2016  \
# case_identifier
# 779               0.358        Republican Party  In the Democratic primary
# 2108              0.563        Republican Party  In the Republican primary
# 2597              0.552        Republican Party  In the Democratic primary
# 4148              0.208        Democratic Party  In the Democratic primary
# 4460              0.334        Republican Party  In the Republican primary
#
#                 pp_demprim16_2016 pp_repprim16_2016 inputstate_2016  \
# case_identifier
# 779               Hillary Clinton               NaN      California
# 2108                          NaN      Donald Trump         Arizona
# 2597              Hillary Clinton               NaN       Wisconsin
# 4148                 Someone else               NaN        Oklahoma
# 4460                          NaN       Marco Rubio           Texas
#
# ...

# %%
# Out:
# case_identifier
# 779     __NA__
# 2108    __NA__
# 2597    __NA__
# 4148    __NA__
# 4460    __NA__
# Name: votemeth16_rnd_2016, dtype: object

# %%
list(data.columns)
# Out:
# ['weight',
#  'PARTY_AGENDAS_rand_2016',
#  'pp_primary16_2016',
#  'pp_demprim16_2016',
#  'pp_repprim16_2016',
#  'inputstate_2016',
#  'izip_2016',
#  'votereg2_2016',
#  'votereg_f_2016',
#  'regzip_2016',
#  'turnout16_2016',
#  'vote_usual_2016',
#  'votemeth16_2016',
#  'presvote16post_2016',
#  'presvote16post_t_2016',
#  'vote2016_cand2_2016',
#  'vote_for_against_2016',
#  'Clinton_Rubio_2016',
#  'Clinton_Cruz_2016',
#  'Sanders_Trump_2016',
#  'Sanders_Rubio_2016',
#  'wished_voted_2016',
#  'vote_regrets_2016',
#  'second_chance_2016',
#  'second_chance_t_2016',
#  'accurately_counted_2016',
#  'accurately_counted2_2016',
#  'obamaapp_2016',
#  'fav_trump_2016',
#  'fav_cruz_2016',
#  'fav_ryan_2016',
#  'fav_romn_2016',
#  'fav_obama_2016',
#  'fav_hrc_2016',
#  'fav_sanders_2016',
#  'fav_rubio_2016',
#  'PARTY_AGENDAS_D1_2016',
#  'PARTY_AGENDAS_D2_2016',
#  'PARTY_AGENDAS_D3_2016',
#  'PARTY_AGENDAS_D4_2016',
#  'PARTY_AGENDAS_D5_2016',
#  'PARTY_AGENDAS_D6_2016',
# ...

# %%
data = data.drop(columns={'regzip_2016', 'inputstate_2016', 'izip_2016', 'votereg2_2016', 'votereg_f_2016',
                          'regzip_2016', 'turnout16_2016', 'vote_usual_2016', 'votemeth16_2016', 'presvote16post_t_2016',
                          'wished_voted_2016', 'vote_regrets_2016', 'second_chance_2016', 'second_chance_t_2016', 'race_other_2016', 'religpew_t_2016',
                          'religpew_t_2016', 'votemeth16_rnd_2016', 'presvote16post_rnd_2016',
                          'vote2016_cand2_rnd_2016', 'Clinton_Rubio_rnd_2016', 'Clinton_Cruz_rnd_2016',
                          'Sanders_Trump_rnd_2016', 'Sanders_Rubio_rnd_2016', 'second_chance_rnd_2016',
                          'obamaapp_rnd_2016', 'fav_grid_row_rnd_2016', 'fav_grid_col_rnd_2016',
                          'PARTY_AGENDAS_D_grid_row_rnd_201', 'PARTY_AGENDAS_R_grid_row_rnd_201',
                          'RIGGED_SYSTEM_grid_row_rnd_2016', 'track_rnd_2016', 'persfinretro_rnd_2016',
                          'econtrend_rnd_2016', 'Americatrend_rnd_2016', 'futuretrend_rnd_2016',
                          'wealth_rnd_2016', 'values_culture_rnd_2016', 'US_respect_rnd_2016',
                          'trust_people_rnd_2016', 'helpful_people_rnd_2016', 'fair_people_rnd_2016',
                          't1_grid_row_rnd_2016', 'imiss_row_rnd_2016', 'imiss_col_rnd_2016',
                          'immi_contribution_rnd_2016', 'immi_naturalize_rnd_2016', 'immi_makedifficult_rnd_2016',
                          'immi_muslim_rnd_2016', 'abortview3_rnd_2016', 'gaymar_rnd_2016',
                          'view_transgender_rnd_2016', 'deathpen_rnd_2016', 'police_threat_rnd_2016',
                          'conviction_accuracy_rnd_2016', 'healthreformbill_rnd_2016', 'envwarm_rnd_2016',
                          'envpoll2_rnd_2016', 'affirmact_gen_rnd_2016', 'taxdoug_rnd_2016',
                          'gvmt_involment_rnd_2016', 'tradepolicy_rnd_2016', 'free_trade_grid_row_rnd_2016',
                          'agree_grid_row_rnd_2016', 'proud_grid_row_rnd_2016', 'CONCEPTIONS_grid_row_rnd_2016', 
                          'sexism_grid_row_rnd_2016', 'gender_equality_rnd_2016', 'racialresent_grid_row_rnd_2016',
                          'race_majority_row_rnd_2016', 'm_SC_1_SC_4_rnd_2016', 'SOCIAL_CONFORMITY_1_grid_col_rnd',
                          'SOCIAL_CONFORMITY_2_grid_col_rnd', 'SOCIAL_CONFORMITY_3_grid_col_rnd',
                          'SOCIAL_CONFORMITY_4_grid_col_rnd', 'POLITICAL_CORRECTNESS_rnd_2016', 'gunown_rnd_2016',
                          'imissf2_baseline', 'match_generic_t_baseline', 'PARTYID_SP_baseline',
                          'therm_baseline', 'add_confirm_baseline', 'inputzip_baseline', 'votereg_baseline',
                          'votereg_f_baseline', 'regzip_baseline', 'votereg_fnd_baseline', 'regzip2_baseline',
                          'inputstate_baseline', 'urbancity_t_baseline', 'ownhome_t_baseline', 'partyreg_t_baseline',
                          'reliablevoter_baseline', 'straighttic_baseline', 'voted08_ccap_baseline',
                          'OTpresvote08_baseline', 'vote10_baseline', 'congvote10_ccap_baseline', 'fav_romn_baseline',
                          'fav_ging_baseline', 'fav_hunt_baseline', 'fav_bach_baseline', 'fav_ronp_baseline',
                          'fav_sant_baseline', 'fav_perr_baseline', 'fav_obama_baseline', 'fav_hrc_baseline',
                          'fav_biden_baseline', 'ideoobama_baseline', 'saysobama_baseline', 'likeobama_baseline',
                          'ideonewt_baseline', 'saysnewt_baseline', 'likenewt_baseline', 'ideoromney_baseline',
                          'saysromney_baseline', 'likeromney_baseline', 'repchoice_baseline', 'repnom_baseline',
                          'repnom_t_baseline', 'repnom_f_baseline', 'repnom_f_t_baseline', 'cmatch_romn_baseline',
                          'cmatch_romn_t_baseline', 'cmatch_romn_f_baseline', 'cmatch_ging_baseline',
                          'cmatch_ging_t_baseline', 'cmatch_ging_f_baseline', 'cmatch_paul_baseline',
                          'cmatch_paul_t_baseline', 'cmatch_paul_f_baseline', 'volunteerf_baseline',
                          'polcontr_t_baseline', 'polcontr_1_baseline', 'polcontr_2_baseline',
                          'polcontr_3_baseline', 'polcontr_4_baseline', 'polcontr_5_baseline',
                          'polcontr_6_baseline', 'polcontr_7_baseline', 'religpew_protestant_t_baseline',
                          'Xreligpew_protestant_baseline', 'religpew_protestant_baseline', 'religpew_protestant_t_baseline',
                          'religpew_t_baseline', 'religpew_protestant_baseline', 'religpew_protestant_t_baseline',
                          'Xreligpew_protestant_baseline', 'religpew_baptist_baseline',
                          'religpew_baptist_t_baseline', 'religpew_methodist_baseline',
                          'religpew_methodist_t_baseline', 'religpew_nondenom_baseline',
                          'religpew_nondenom_t_baseline', 'religpew_lutheran_baseline',
                          'religpew_lutheran_t_baseline', 'religpew_presby_baseline', 'religpew_presby_t_baseline',
                          'religpew_pentecost_baseline', 'religpew_pentecost_t_baseline',
                          'religpew_episcop_baseline', 'religpew_episcop_t_baseline', 'religpew_christian_baseline',
                          'religpew_christian_t_baseline', 'religpew_congreg_baseline', 'religpew_congreg_t_baseline',
                          'religpew_holiness_baseline', 'religpew_holiness_t_baseline', 'religpew_reformed_baseline',
                          'religpew_reformed_t_baseline', 'religpew_advent_baseline', 'religpew_advent_t_baseline',
                          'religpew_catholic_baseline', 'religpew_catholic_t_baseline', 'religpew_mormon_baseline',
                          'religpew_mormon_t_baseline', 'religpew_orthodox_baseline', 'religpew_orthodox_t_baseline',
                          'religpew_jewish_baseline', 'religpew_jewish_t_baseline', 'religpew_muslim_baseline',
                          'religpew_muslim_t_baseline', 'religpew_buddhist_baseline', 'religpew_buddhist_t_baseline',
                          'religpew_hindu_baseline', 'religpew_hindu_t_baseline', 'milstat_insert_baseline',
                          'healthcov_t_baseline', 'gender_baseline', 'race_baseline', 'race_other_baseline',
                          'educ_baseline', 'child18_baseline', 'child18num_baseline', 'employstat2_t_baseline',
                          'naics3_baseline', 'naics3_t_baseline', 'occupationother_baseline',
                          'employ_spouse_baseline', 'employ_spouse_t_baseline', 'faminc_baseline', 'cand_baseline',
                          'cdid_baseline', 'demnom2_baseline', 'demnom_t_baseline', 'izip_baseline',
                          'lookupzip_baseline', 'prim12_baseline', 'statefips_baseline', 'ccap2012_post_2016',
                          'post_inputstate_2012', 'post_cdid113_2012', 'post_turnout12_2012',
                          'post_turnout_method12_2012', 'post_presvote12_2012', 'post_presvote12_other_2012',
                          'post_senvote12_2012', 'post_senvote12_other_2012', 'post_house12_2012',
 'post_housevote12_other_2012',
 'post_pid7_2012',
 'post_pid3_t_2012',
 'post_pid3_2012',
 'post_ideo5_2012',
 'post_newsint_2012',
 'post_HouseCand1Name_2012',
 'post_HouseCand1Party_2012',
 'post_HouseCand2Name_2012',
 'post_HouseCand2Party_2012',
 'post_HouseCand3Name_2012',
 'post_HouseCand3Party_2012',
 'post_SenCand1Name_2012',
 'post_SenCand1Party_2012',
 'post_SenCand2Name_2012',
 'post_SenCand2Party_2012',
 'post_SenCand3Name_2012',
 'post_SenCand3Party_2012',
 'starttime_2016',
 'endtime_2016'})

# %%
data = data.rename(columns={'PARTY_AGENDAS_rand_2016':'registered_party_2016', 'pp_primary16_2016': 'primary_2016',
                           'pp_demprim16_2016': 'demprimary_2016', 'pp_repprim16_2016': 'repprimary_2016',
                           'inputstate_2016': 'state_2016', 'izip_2016': 'zip_2016', 'votereg2_2016': 'registered_2016',
                           'votereg_f_2016': 'same_zip_2016', 'turnout16_2016': 'voted_2016', 'presvote16post_2016': 'presvote_2016',
                           'presvote16post_t_2016': 'vote_other_text', 'vote2016_cand2_2016': 'no_vote_preferred_2016',
                           'Clinton_Rubio_2016': 'clinton_rubio_2016', 'Clinton_Cruz_2016': 'clinton_cruz_2016',
                           'Sanders_Trump_2016': 'sanders_trump_2016', 'Sanders_Rubio_2016': 'sanders_rubio_2016',
                           'second_chance_t_2016': "second_chance_other_text", 'accurately_counted_2016': 'accurately_counted_your_2016',
                           'accurately_counted2_2016': 'accurately_counted_country_2016', 'PARTY_AGENDAS_D1_2016': 'dem_1',
                           'PARTY_AGENDAS_D2_2016': 'dem_2', 'PARTY_AGENDAS_D3_2016': 'dem_3', 'PARTY_AGENDAS_D4_2016': 'dem_4',
                           'PARTY_AGENDAS_D5_2016': 'dem_5', 'PARTY_AGENDAS_D6_2016': 'dem_6', 'PARTY_AGENDAS_D7_2016': 'dem_7',
                           'PARTY_AGENDAS_D8_2016': 'dem_8', 'PARTY_AGENDAS_D9_2016': 'dem_9', 'PARTY_AGENDAS_D10_2016': 'dem_10',
                           'PARTY_AGENDAS_D11_2016': 'dem_11', 'PARTY_AGENDAS_D12_2016': 'dem_12', 'PARTY_AGENDAS_R1_2016': 'rep_1',
                           'PARTY_AGENDAS_R2_2016': 'rep_2', 'PARTY_AGENDAS_R3_2016': 'rep_3', 'PARTY_AGENDAS_R4_2016': 'rep_4',
                           'PARTY_AGENDAS_R5_2016': 'rep_5', 'PARTY_AGENDAS_R6_2016': 'rep_6', 'PARTY_AGENDAS_R7_2016': 'rep_7',
                           'PARTY_AGENDAS_R8_2016': 'rep_8', 'PARTY_AGENDAS_R9_2016': 'rep_9', 'PARTY_AGENDAS_R10_2016': 'rep_10',
                           'PARTY_AGENDAS_R11_2016': 'rep_11', 'PARTY_AGENDAS_R12_2016': 'rep_12', 'RIGGED_SYSTEM_1_2016': 'rigged_1',
                           'RIGGED_SYSTEM_2_2016': 'rigged_2', 'RIGGED_SYSTEM_3_2016': 'rigged_3', 'RIGGED_SYSTEM_4_2016': 'rigged_4',
                           'RIGGED_SYSTEM_5_2016': 'rigged_5', 'RIGGED_SYSTEM_6_2016': 'rigged_6', 'track_2016': 'on_track_2016',
                           'persfinretro_2016': 'finances_changed',
                           ''})

# %%
list(data.columns)
# Out:
# ['weight',
#  'registered_party_2016',
#  'primary_2016',
#  'demprimary_2016',
#  'repprimary_2016',
#  'state_2016',
#  'zip_2016',
#  'registered_2016',
#  'same_zip_2016',
#  'regzip_2016',
#  'voted_2016',
#  'vote_usual_2016',
#  'votemeth16_2016',
#  'presvote_2016',
#  'vote_other_text',
#  'no_vote_preferred_2016',
#  'vote_for_against_2016',
#  'clinton_rubio_2016',
#  'clinton_cruz_2016',
#  'sanders_trump_2016',
#  'sanders_rubio_2016',
#  'wished_voted_2016',
#  'vote_regrets_2016',
#  'second_chance_2016',
#  'second_chance_other_text',
#  'accurately_counted_your_2016',
#  'accurately_counted_country_2016',
#  'obamaapp_2016',
#  'fav_trump_2016',
#  'fav_cruz_2016',
#  'fav_ryan_2016',
#  'fav_romn_2016',
#  'fav_obama_2016',
#  'fav_hrc_2016',
#  'fav_sanders_2016',
#  'fav_rubio_2016',
#  'dem_1',
#  'dem_2',
#  'dem_3',
#  'dem_4',
#  'dem_5',
#  'dem_6',
#  'dem_7',
#  'dem_8',
#  'dem_9',
#  'dem_10',
#  'dem_11',
#  'dem_12',
#  'rep_1',
#  'rep_2',
#  'rep_3',
# ...
